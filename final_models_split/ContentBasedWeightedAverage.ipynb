# %%
# %run helper.ipynb

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC

# %%
class ContentBasedWeightedAverageModel:
    
    def __init__(self, meta_df, X_train, y_train):        
        X_train['overall'] = y_train
        self._user_product_matrix = pd.crosstab(X_train.reviewerID, X_train.asin, X_train.overall, aggfunc='max')
        
        tfidf = TfidfVectorizer(smooth_idf = False, sublinear_tf = True)
        tfidf_matrix = tfidf.fit_transform(meta_df['metadata'])
        content_correlation = cosine_similarity(tfidf_matrix, tfidf_matrix)
        self._similarity = pd.DataFrame(content_correlation, index=meta_df.asin.tolist(), columns=meta_df.asin.tolist())
        self._similarity = self._similarity.drop_duplicates()
        self._similarity = self._similarity.loc[:,~self._similarity.columns.duplicated()]
        
    def predict(self, X):
        results = np.array([])
        for i, row in X.iterrows():
            results = np.append(results, self._predict(row))
        return results            
    
    def _predict(self, X):
        if X['asin'] in self._similarity and X['asin'] in self._similarity.index and X['reviewerID'] in self._user_product_matrix.index:
            ratings_scores = self._user_product_matrix.loc[X['reviewerID']] 
            ratings_scores = ratings_scores.dropna()
            
            if len(ratings_scores.index.values) > 0:
                sim_scores = self._similarity[X['asin']]
                if all(i in sim_scores.index.values for i in ratings_scores.index.values):
                    sim_scores = sim_scores.loc[ratings_scores.index.values]
                    if sim_scores.sum() != 0:
                        return np.dot(ratings_scores, sim_scores)/sim_scores.sum()
        
        return 2.5

# %%
X_train, y_train = load_train(subset_name)
X_test, y_test = load_test(subset_name)
meta = load_meta(subset_name)

# %%
model = ContentBasedWeightedAverageModel(meta, X_train, y_train)
y_pred = model.predict(X_test)
print_score(y_test, y_pred)
# Out:
# RMSE: 2.013653702055771
# MAE: 1.872760358342665

# %%
save_preds(model, subset_name, y_pred)

# %%
X_train
# Out:
#        Unnamed: 0.1  Unnamed: 0        asin      reviewerID  \
# 0              2444      194387  B0000025P9  A1IKOYZVFHO1XP
# 1              2968      231193  B0000026WD  A2PV6GK1HV54Y9
# 2             23691     2732064  B0169PLOV8  A1HCCW38EQQBTY
# 3              4204      309611  B000002H33  A2C7BOQVFH1HLE
# 4             14170     1078731  B00006HCUT  A3O8YT41TDXL0B
# ...             ...         ...         ...             ...
# 11899          8164      549727  B000003BEU  A26NLSTT75FMJM
# 11900         15715     1180942  B00009WHRT  A200C7YQJ45LRR
# 11901          9142      716286  B00000F1D3   AWPODHOB4GFWL
# 11902         10489      821878  B00003TFN7  A1JIW8GOSSGUQR
# 11903         14814     1122960  B00007IT8S  A14W8HXP3RM3ZS
#
#                                                 sentence  \
# 0      In the spring of 1982,Toto graced radio airwav...
# 1      Dangerous by Michael Jackson could easily be h...
# 2      Yes, he's still explicit.  Yes, he and Trey So...
# 3      Metallica is boldly and appropriately named as...
# 4      ...or those who don't mind buying an album sim...
# ...                                                  ...
# 11899  These Stones role doobies! This album should s...
# 11900  Now, people that know me know that I hardly ev...
# 11901  "Believe" was one of those instant classic son...
# 11902  Judas Priest enjoyed most of its success throu...
# 11903  JAMES TAYLOR-THE BEST OF JAMES TAYLOR: As an u...
#
#                                           clean_sentence  \
# 0      in the spring of 1982 toto graced radio airwav...
# 1      dangerous by michael jackson could easily be h...
# 2      yes  he  still explicit   yes  he and trey son...
# 3      metallica is boldly and appropriately named as...
# 4         or those who don t mind buying an album sim...
# ...                                                  ...
# 11899  these stones role doobies  this album should s...
# 11900  now  people that know me know that i hardly ev...
# 11901   believe  was one of those instant classic son...
# 11902  judas priest enjoyed most of its success throu...
# 11903  james taylor the best of james taylor  as an u...
#
#                                         tok_lem_sentence  \
# 0      ['in', 'the', 'spring', 'of', '1982', 'toto', ...
# 1      ['dangerous', 'by', 'michael', 'jackson', 'cou...
# 2      ['yes', 'he', 'still', 'explicit', 'yes', 'he'...
# 3      ['metallica', 'is', 'boldly', 'and', 'appropri...
# 4      ['or', 'those', 'who', 'don', 't', 'mind', 'bu...
# ...                                                  ...
# 11899  ['these', 'stone', 'role', 'doobies', 'this', ...
# 11900  ['now', 'people', 'that', 'know', 'me', 'know'...
# 11901  ['believe', 'wa', 'one', 'of', 'those', 'insta...
# 11902  ['juda', 'priest', 'enjoyed', 'most', 'of', 'i...
# 11903  ['james', 'taylor', 'the', 'best', 'of', 'jame...
#
#                                                 metadata
# 0                                                   toto
# 1                                              dangerous
# 2      span parentaladvisory class size medium color ...
# 3                                         master puppets
# 4                                                whitney
# ...                                                  ...
# 11899                          satanic majesties request
# 11900  span parentaladvisory class size medium color ...
# 11901                                            believe
# 11902                                  sad wings destiny
# 11903                                  best james taylor
#
# [11904 rows x 8 columns]
